# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6,7,8]
y = [3,1,5,2,5,8,9,4]
plt.scatter(x,y, label ="SkitScat", color= "k")

plt.xlabel('x')
plt.ylabel('y')
plt.title("Intrsesting graph")
plt.legend()
plt.show()
